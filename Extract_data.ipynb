# %%
import pandas as pd
import re

def parse_intermediate_range(i_val):
    """
    Helper function to parse the 'I' or 'ATU' column.
    Handles '18-19', '18', and '-'
    """
    i_val = str(i_val).strip()
    range_match = re.match(r"(\d+)-(\d+)", i_val)
    if range_match:
        return int(range_match.group(1)), int(range_match.group(2))
    
    single_num_match = re.fullmatch(r"(\d+)", i_val)
    if single_num_match:
        num = int(single_num_match.group(1))
        return num, num # Min and Max are the same
    
    return None, None

def parse_breakpoint_value(val):
    """
    Helper function to extract the first number from S or R columns.
    Handles '>= 18' or '< 17' or just '18'
    """
    val = str(val).strip()
    num_match = re.search(r"(\d+)", val)
    if num_match:
        return int(num_match.group(1))
    return None

# --- THIS FUNCTION IS NEW AND CORRECTED ---
def find_header_rows(df):
    """
    Scans the raw DataFrame to find the row index of the *second* header row
    (the one with "S ≥" and "R <").
    """
    # Check the first 15 rows
    for i, row in df.head(15).iterrows():
        found_S = False
        found_R = False
        
        # Check every cell in the row for the exact strings
        for cell in row:
            cell_str = str(cell).strip()
            if cell_str == "S ≥":
                found_S = True
            if cell_str == "R <":
                found_R = True
        
        # If both keywords are in the same row, this is our second header row
        if found_S and found_R:
            return i - 1  # Return the index of the *first* header row
            
    return None # Did not find the header row
# --- END NEW FUNCTION ---

def extract_all_breakpoints():
    """
    Reads the Excel file, dynamically finds the header on each sheet,
    and extracts the S/I/R data.
    """
    
    excel_file_path = "v_15.0_Breakpoint_Tables.xlsx"

    BLACKLIST_SHEETS = [
        "Content", "Changes", "Notes", "Guidance", "Dosages", 
        "Technical uncertainty", "PK PD breakpoints", "PK PD cutoffs",
        "Topical agents", "M.tuberculosis", "L.pneumophila"
    ]

    all_breakpoint_data = []

    try:
        try:
            xls = pd.ExcelFile(excel_file_path)
        except FileNotFoundError:
            print(f"ERROR: File not found at '{excel_file_path}'")
            return []

        all_sheet_names = xls.sheet_names
        print(f"Found {len(all_sheet_names)} sheets. Processing...")

        for sheet_name in all_sheet_names:
            
            if sheet_name.strip() in BLACKLIST_SHEETS:
                print(f"-> Skipping sheet (in blacklist): {sheet_name}")
                continue

            microbe_name = sheet_name.strip()
            print(f"Processing data for: {microbe_name}")

            try:
                # 1. Read the sheet with NO header
                df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None)

                # 2. Find the index of the header row (using the NEW function)
                header_index = find_header_rows(df_raw)
                
                if header_index is None:
                    print(f"  -> Could not find 'S ≥' and 'R <' header row in {microbe_name}. Skipping.")
                    continue
                
                # 3. Re-create the DataFrame with the correct header
                header_1 = df_raw.iloc[header_index].ffill()
                header_2 = df_raw.iloc[header_index + 1]
                df_columns = pd.MultiIndex.from_arrays([header_1, header_2])
                
                df_data = df_raw.iloc[header_index + 2:]
                df_data.columns = df_columns
                df_data = df_data.reset_index(drop=True)

                # --- 4. Dynamic Column Finding Logic ---
                s_col, r_col, i_col = None, None, None
                antibiotic_col = df_data.columns[0] # Assume first col is antibiotic

                for col in df_data.columns:
                    parent_header = str(col[0])
                    sub_header = str(col[1]).strip()
                    
                    if "Zone diameter breakpoints (mm)" in parent_header or "Disk diffusion" in parent_header:
                        
                        # --- THIS IS THE FIX ---
                        if sub_header == "S ≥": s_col = col
                        if sub_header == "R <": r_col = col
                        if sub_header == "ATU": i_col = col
                        # ---
                        
                        # Fallback for other formats
                        if "S (>= mm)" == sub_header: s_col = col
                        if "R (<= mm)" == sub_header: r_col = col
                        if "I (mm)" == sub_header: i_col = col
                        if "ATU S >=" == sub_header: s_col = col
                        if "ATU B" == sub_header: i_col = col

                if not s_col or not r_col:
                    print(f"  -> S/R breakpoint columns not found. Skipping.")
                    continue

                # --- 5. Extract Data ---
                columns_to_extract = [antibiotic_col, s_col, r_col]
                column_names = ['Antibiotic', 'S_col', 'R_col']
                
                if i_col:
                    columns_to_extract.append(i_col)
                    column_names.append('I_col')

                data_subset = df_data[columns_to_extract].copy()
                data_subset.columns = column_names
                data_subset = data_subset.dropna(subset=['Antibiotic'])

                for index, row in data_subset.iterrows():
                    medicine_name = str(row['Antibiotic']).strip()
                    # Skip rows that are just headers or notes
                    if medicine_name.lower() in ["antibiotic", "penicillins", "cephalosporins", "carbapenems", "monobactams", "fluoroquinolones", "aminoglycosides", "glycopeptides and lipoglycopeptides", "macrolides, lincosamides and streptogramins", "tetracyclines", "oxazolidinones", "miscellaneous agents"]:
                        continue 

                    s_min = parse_breakpoint_value(row['S_col'])
                    
                    r_raw_val = parse_breakpoint_value(row['R_col'])
                    r_max = None
                    if r_raw_val is not None:
                        r_col_name = str(r_col[1]).strip() # Check the sub-header name
                        if r_col_name == "R <" or r_col_name == "ATU R <":
                            r_max = r_raw_val - 1 # Logic: "R < 18" means R is <= 17
                        else:
                            r_max = r_raw_val # Logic: "R (<= mm)" or just "17"
                    
                    i_min, i_max = (None, None)
                    if 'I_col' in row:
                        i_min, i_max = parse_intermediate_range(row['I_col'])

                    all_breakpoint_data.append({
                        "microbe_name": microbe_name,
                        "medicine_name": medicine_name,
                        "susceptible_min_mm": s_min,
                        "resistant_max_mm": r_max,
                        "intermediate_min_mm": i_min,
                        "intermediate_max_mm": i_max
                    })

            except Exception as e:
                print(f"  -> ERROR processing sheet {sheet_name}: {e}")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return []

    print("\n--- Data Extraction Complete ---")
    return all_breakpoint_data

# --- Run the function ---
structured_data = extract_all_breakpoints()

if structured_data:
    print(f"\nTotal rules extracted: {len(structured_data)}")
    
    # Save to a new, clean CSV
    final_df = pd.DataFrame(structured_data)
    final_df.to_csv("cleaned_breakpoints_final.csv", index=False)
    print("\nSuccessfully saved all data to 'cleaned_breakpoints_final.csv'")
    
    print("\n--- First 5 Entries ---")
    print(final_df.head())
# Out:
# Found 41 sheets. Processing...
# -> Skipping sheet (in blacklist): Content
# -> Skipping sheet (in blacklist): Changes
# -> Skipping sheet (in blacklist): Notes
# -> Skipping sheet (in blacklist): Guidance
# -> Skipping sheet (in blacklist): Dosages
# -> Skipping sheet (in blacklist): Technical uncertainty
# Processing data for: Enterobacterales
# Processing data for: Pseudomonas
# Processing data for: S.maltophilia
# Processing data for: Acinetobacter
# Processing data for: Staphylococcus
# Processing data for: Enterococcus
# Processing data for: Streptococcus A,B,C,G
# Processing data for: S.pneumoniae
# Processing data for: Viridans group streptococci
# Processing data for: H.influenzae
# Processing data for: M.catarrhalis
# Processing data for: N.gonorrhoeae
#   -> Could not find 'S ≥' and 'R <' header row in N.gonorrhoeae. Skipping.
# Processing data for: N.meningitidis
#   -> Could not find 'S ≥' and 'R <' header row in N.meningitidis. Skipping.
# Processing data for: Anaerobic bacteria
# Processing data for: H.pylori
#   -> Could not find 'S ≥' and 'R <' header row in H.pylori. Skipping.
# Processing data for: L.monocytogenes
# Processing data for: Pasteurella
# Processing data for: C.jejuni_C.coli
# Processing data for: Corynebacterium
# Processing data for: C.diphtheriae_C.ulcerans
# Processing data for: A.sanguinicola_A.urinae
# Processing data for: K.kingae
# Processing data for: Aeromonas
# Processing data for: A.xylosoxidans
# Processing data for: Vibrio
# Processing data for: Bacillus
# Processing data for: B.anthracis
# Processing data for: B.melitensis
# Processing data for: B.pseudomallei
# Processing data for: B.cepacia
#   -> Could not find 'S ≥' and 'R <' header row in B.cepacia. Skipping.
# -> Skipping sheet (in blacklist): L.pneumophila
# -> Skipping sheet (in blacklist): M.tuberculosis
# -> Skipping sheet (in blacklist): Topical agents
# -> Skipping sheet (in blacklist): PK PD breakpoints
# -> Skipping sheet (in blacklist): PK PD cutoffs
#
# --- Data Extraction Complete ---
#
# Total rules extracted: 1205
#
# Successfully saved all data to 'cleaned_breakpoints_final.csv'
#
# --- First 5 Entries ---
#        microbe_name                                      medicine_name  \
# 0  Enterobacterales                                   Benzylpenicillin
# 1  Enterobacterales                                     Ampicillin iv1
# 2  Enterobacterales          Ampicillin oral (uncomplicated UTI only)1
# 3  Enterobacterales                           Ampicillin-sulbactam iv1
# 4  Enterobacterales  Ampicillin-sulbactam oral (uncomplicated UTI o...
#
#    susceptible_min_mm  resistant_max_mm  intermediate_min_mm  \
# 0                 NaN               NaN                  NaN
# 1                14.0              13.0                  NaN
# 2                14.0              13.0                  NaN
# 3                14.0              13.0                  NaN
# 4                14.0              13.0                  NaN
#
#    intermediate_max_mm
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
structured_data
# Out:
# [{'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Benzylpenicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ampicillin iv1',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ampicillin oral (uncomplicated UTI only)1',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ampicillin-sulbactam iv1',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ampicillin-sulbactam oral (uncomplicated UTI only)1',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin iv1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin oral (infections originating from the urinary tract)1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin oral (uncomplicated UTI only)1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin oral (other indications)1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin-clavulanic acid iv1',
#   'susceptible_min_mm': 19,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': 19,
#   'intermediate_max_mm': 20},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin-clavulanic acid oral (infections originating from the urinary tract)1',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': 19,
#   'intermediate_max_mm': 20},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin-clavulanic acid oral (uncomplicated UTI only)1',
#   'susceptible_min_mm': 16,
#   'resistant_max_mm': 15,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amoxicillin-clavulanic acid oral (other indications)1',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': 19,
#   'intermediate_max_mm': 20},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Piperacillin',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Piperacillin-tazobactam',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': 19,
#   'intermediate_max_mm': 19},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ticarcillin-clavulanic acid',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Temocillin (infections originating from the urinary tract), E. coli, Klebsiella spp. (except K. aerogenes) and P. mirabilis',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Phenoxymethylpenicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Oxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Dicloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Flucloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Mecillinam oral (pivmecillinam) (uncomplicated UTI only), E. coli, Citrobacter spp., Klebsiella\xa0spp.,\xa0Raoultella spp., Enterobacter\xa0spp. and P. mirabilis',
#   'susceptible_min_mm': 15,
#   'resistant_max_mm': 14,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cephalosporins1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefaclor (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefadroxil (uncomplicated UTI only)',
#   'susceptible_min_mm': 12,
#   'resistant_max_mm': 11,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefalexin (uncomplicated UTI only)',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefazolin (infections originating from the urinary tract), E. coli and Klebsiella spp. (except K. aerogenes)',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefepime',
#   'susceptible_min_mm': 27,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefepime-enmetazobactam',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': 21,
#   'intermediate_max_mm': 22},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefiderocol',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': 21,
#   'intermediate_max_mm': 23},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefixime (uncomplicated UTI only)',
#   'susceptible_min_mm': 17,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefotaxime (indications other than meningitis)',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefotaxime (meningitis)',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefoxitin (screen only)5',
#   'susceptible_min_mm': 19,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefpodoxime \n(uncomplicated UTI only)',
#   'susceptible_min_mm': 21,
#   'resistant_max_mm': 20,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftaroline',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': 22,
#   'intermediate_max_mm': 23},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftazidime',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftazidime-avibactam',
#   'susceptible_min_mm': 13,
#   'resistant_max_mm': 12,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftibuten (infections originating from the urinary tract)',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftobiprole',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftolozane-tazobactam7',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': 19,
#   'intermediate_max_mm': 21},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftriaxone (indications other than meningitis)',
#   'susceptible_min_mm': 27,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ceftriaxone (meningitis)',
#   'susceptible_min_mm': 27,
#   'resistant_max_mm': 26,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefuroxime iv, E. coli, Klebsiella spp. (except K. aerogenes), Raoultella spp. and P. mirabilis',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Cefuroxime oral (uncomplicated UTI only), E. coli, Klebsiella spp. (except K. aerogenes), Raoultella spp. and P. mirabilis',
#   'susceptible_min_mm': 19,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Carbapenems1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Doripenem',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 20,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ertapenem',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Imipenem, Enterobacterales except Morganellaceae',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Imipenem2, Morganellaceae',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Imipenem-relebactam, Enterobacterales except Morganellaceae',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': 20,
#   'intermediate_max_mm': 22},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Meropenem (indications other than meningitis)',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 15,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Meropenem (meningitis)',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Meropenem-vaborbactam',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': 15,
#   'intermediate_max_mm': 19},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Aztreonam1',
#   'susceptible_min_mm': 26,
#   'resistant_max_mm': 20,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Aztreonam-avibactam',
#   'susceptible_min_mm': 25,
#   'resistant_max_mm': 24,
#   'intermediate_min_mm': 22,
#   'intermediate_max_mm': 24},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ciprofloxacin, Salmonella spp.1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ciprofloxacin (indications other than meningitis)',
#   'susceptible_min_mm': 25,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': 22,
#   'intermediate_max_mm': 24},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ciprofloxacin (meningitis)2',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Pefloxacin (screen only)',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Delafloxacin, E. coli',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Levofloxacin',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 18,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Moxifloxacin, Enterobacterales except Morganella morganii, Proteus spp. and Serratia spp.3',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Nalidixic acid (screen only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Norfloxacin (uncomplicated UTI only)',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Ofloxacin',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Aminoglycosides1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amikacin (systemic infections)',
#   'susceptible_min_mm': 18,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Amikacin (infections originating from the urinary tract)',
#   'susceptible_min_mm': 18,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Gentamicin (systemic infections)',
#   'susceptible_min_mm': 17,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Gentamicin (infections originating from the urinary tract)',
#   'susceptible_min_mm': 17,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Netilmicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Tobramycin (systemic infections)',
#   'susceptible_min_mm': 16,
#   'resistant_max_mm': 15,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Tobramycin (infections originating from the urinary tract)',
#   'susceptible_min_mm': 16,
#   'resistant_max_mm': 15,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Dalbavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Oritavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Teicoplanin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Telavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Vancomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Azithromycin1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Clarithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Erythromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Roxithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Clindamycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Quinupristin-dalfopristin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Doxycycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Eravacycline, E. coli',
#   'susceptible_min_mm': 17,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Minocycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Tetracycline1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Tigecycline, E. coli and C. koseri',
#   'susceptible_min_mm': 18,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Linezolid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Tedizolid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Chloramphenicol',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Colistin2',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Daptomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Fosfomycin iv (infections originating from the urinary tract), E. coli',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Fosfomycin iv (other indications), \nE. coli',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Fosfomycin iv, other Enterobacterales',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Fosfomycin oral \n(uncomplicated UTI only), E. coli',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Fusidic acid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Lefamulin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Metronidazole',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Nitrofurantoin (uncomplicated UTI only), E. coli',
#   'susceptible_min_mm': 11,
#   'resistant_max_mm': 10,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Nitroxoline (uncomplicated UTI only), \nE. coli',
#   'susceptible_min_mm': 15,
#   'resistant_max_mm': 14,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Rifampicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Spectinomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Trimethoprim \n(uncomplicated UTI only)',
#   'susceptible_min_mm': 15,
#   'resistant_max_mm': 14,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Trimethoprim-sulfamethoxazole7',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 10,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'Examples of inhibition zones for Escherichia coli with fosfomycin.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'a-c) Ignore all colonies and read the outer zone edge.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Enterobacterales',
#   'medicine_name': 'd) Record as no inhibition zone.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Benzylpenicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ampicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ampicillin-sulbactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Amoxicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Amoxicillin-clavulanic acid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Piperacillin',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': 18,
#   'intermediate_max_mm': 19},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Piperacillin-tazobactam',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': 18,
#   'intermediate_max_mm': 19},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ticarcillin-clavulanic acid',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Temocillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Phenoxymethylpenicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Oxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Dicloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Flucloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Mecillinam oral (pivmecillinam) (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefaclor',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefadroxil',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefalexin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefazolin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefepime',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 20,
#   'intermediate_min_mm': 19,
#   'intermediate_max_mm': 23},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefepime-enmetazobactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefiderocol, P. aeruginosa',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': 20,
#   'intermediate_max_mm': 21},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefixime',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefotaxime',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefoxitin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefpodoxime',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftaroline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftazidime',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftazidime-avibactam, P. aeruginosa',
#   'susceptible_min_mm': 17,
#   'resistant_max_mm': 16,
#   'intermediate_min_mm': 16,
#   'intermediate_max_mm': 17},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftibuten',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftobiprole',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftolozane-tazobactam4, P. aeruginosa',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ceftriaxone',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefuroxime iv',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Cefuroxime oral',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Doripenem',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ertapenem',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Imipenem',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Imipenem-relebactam, P. aeruginosa',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Meropenem (indications other than meningitis), P. aeruginosa',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Meropenem (indications other than meningitis), Pseudomonas other than P. aeruginosa',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Meropenem (meningitis), P. aeruginosa',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Meropenem-vaborbactam, \nP. aeruginosa',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Aztreonam',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Aztreonam-avibactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ciprofloxacin',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 25,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Delafloxacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Levofloxacin',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Moxifloxacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Nalidixic acid (screen only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Norfloxacin (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Ofloxacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Aminoglycosides1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Amikacin (systemic infections)',
#   'susceptible_min_mm': 15,
#   'resistant_max_mm': 14,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Amikacin (infections originating from the urinary tract)',
#   'susceptible_min_mm': 15,
#   'resistant_max_mm': 14,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Gentamicin (systemic infections)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Gentamicin (infections originating from the urinary tract)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Netilmicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Tobramycin (systemic infections)',
#   'susceptible_min_mm': 18,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Tobramycin (infections originating from the urinary tract)',
#   'susceptible_min_mm': 18,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Dalbavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Oritavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Teicoplanin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Telavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Vancomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Azithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Clarithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Erythromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Roxithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Clindamycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Quinupristin-dalfopristin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Doxycycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Eravacycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Minocycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Tetracycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Tigecycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Linezolid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Tedizolid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Chloramphenicol',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Colistin1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Daptomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Fosfomycin iv',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Fosfomycin oral',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Fusidic acid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Lefamulin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Metronidazole',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Nitrofurantoin (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Nitroxoline (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Rifampicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Spectinomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Trimethoprim (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Pseudomonas',
#   'medicine_name': 'Trimethoprim-sulfamethoxazole',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Ceftazidime',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Cefepime',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Cefiderocol1',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Aztreonam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Aztreonam-avibactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Ciprofloxacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Levofloxacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Minocycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Tigecycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Trimethoprim-sulfamethoxazole1',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 15,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'Examples of inhibition zones for Stenotrophomonas maltophilia with trimethoprim-sulfamethoxazole.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'a-c) An outer zone can be seen. Read the outer zone edge and interpret according to the breakpoints.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'S.maltophilia',
#   'medicine_name': 'd) Growth up to the disk and no sign of inhibition zone. Report resistant.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Benzylpenicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Ampicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Ampicillin-sulbactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Amoxicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Amoxicillin-clavulanic acid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Piperacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Piperacillin-tazobactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Ticarcillin-clavulanic acid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Temocillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Phenoxymethylpenicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Oxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Cloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Dicloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Flucloxacillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Mecillinam oral (pivmecillinam) (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Cefaclor',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Cefadroxil',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Cefalexin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Acinetobacter',
#   'medicine_name': 'Cefazolin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
# ...
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftaroline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftazidime',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftazidime-avibactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftibuten',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftobiprole',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftolozane-tazobactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ceftriaxone',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 20,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Cefuroxime iv',
#   'susceptible_min_mm': 21,
#   'resistant_max_mm': 17,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Cefuroxime oral',
#   'susceptible_min_mm': 50,
#   'resistant_max_mm': 20,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Doripenem1',
#   'susceptible_min_mm': 30,
#   'resistant_max_mm': 29,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ertapenem1',
#   'susceptible_min_mm': 29,
#   'resistant_max_mm': 28,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Imipenem1',
#   'susceptible_min_mm': 29,
#   'resistant_max_mm': 28,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Imipenem-relebactam2',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Meropenem1',
#   'susceptible_min_mm': 33,
#   'resistant_max_mm': 32,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Meropenem-vaborbactam2',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Aztreonam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Aztreonam-avibactam',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ciprofloxacin',
#   'susceptible_min_mm': 31,
#   'resistant_max_mm': 30,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Delafloxacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Levofloxacin',
#   'susceptible_min_mm': 29,
#   'resistant_max_mm': 28,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Moxifloxacin',
#   'susceptible_min_mm': 26,
#   'resistant_max_mm': 25,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Nalidixic acid (screen only)',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Norfloxacin (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Ofloxacin',
#   'susceptible_min_mm': 28,
#   'resistant_max_mm': 27,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Amikacin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Gentamicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Netilmicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Tobramycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Dalbavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Oritavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Teicoplanin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Telavancin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Vancomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Azithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Clarithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Erythromycin',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Roxithromycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Clindamycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Quinupristin-dalfopristin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Doxycycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Eravacycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Minocycline',
#   'susceptible_min_mm': 25,
#   'resistant_max_mm': 24,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Tetracycline',
#   'susceptible_min_mm': 26,
#   'resistant_max_mm': 25,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Tigecycline',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Linezolid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Tedizolid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Chloramphenicol',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Colistin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Daptomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Fosfomycin iv',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Fosfomycin oral',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Fusidic acid',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Lefamulin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Metronidazole',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Nitrofurantoin (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Nitroxoline (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Rifampicin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Spectinomycin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Trimethoprim (uncomplicated UTI only)',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'M.catarrhalis',
#   'medicine_name': 'Trimethoprim-sulfamethoxazole2',
#   'susceptible_min_mm': 18,
#   'resistant_max_mm': 14,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Ampicillin-sulbactam',
#   'susceptible_min_mm': 25,
#   'resistant_max_mm': 24,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Amoxicillin-clavulanic acid',
#   'susceptible_min_mm': 14,
#   'resistant_max_mm': 13,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Piperacillin-tazobactam3',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Ertapenem',
#   'susceptible_min_mm': 23,
#   'resistant_max_mm': 22,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Imipenem',
#   'susceptible_min_mm': 29,
#   'resistant_max_mm': 28,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Meropenem',
#   'susceptible_min_mm': 28,
#   'resistant_max_mm': 27,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Clindamycin',
#   'susceptible_min_mm': 10,
#   'resistant_max_mm': 9,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Metronidazole',
#   'susceptible_min_mm': 25,
#   'resistant_max_mm': 24,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Prevotella spp.',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Antimicrobial agent',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Benzylpenicillin',
#   'susceptible_min_mm': 20,
#   'resistant_max_mm': 19,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Ampicillin',
#   'susceptible_min_mm': 25,
#   'resistant_max_mm': 24,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Ampicillin-sulbactam',
#   'susceptible_min_mm': 33,
#   'resistant_max_mm': 32,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Amoxicillin',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Amoxicillin-clavulanic acid',
#   'susceptible_min_mm': 24,
#   'resistant_max_mm': 23,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Piperacillin-tazobactam',
#   'susceptible_min_mm': 26,
#   'resistant_max_mm': 25,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Ertapenem',
#   'susceptible_min_mm': 29,
#   'resistant_max_mm': 28,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Imipenem',
#   'susceptible_min_mm': 35,
#   'resistant_max_mm': 34,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Meropenem',
#   'susceptible_min_mm': 34,
#   'resistant_max_mm': 33,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Clindamycin',
#   'susceptible_min_mm': 31,
#   'resistant_max_mm': 30,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Metronidazole',
#   'susceptible_min_mm': 22,
#   'resistant_max_mm': 21,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  {'microbe_name': 'Anaerobic bacteria',
#   'medicine_name': 'Fusobacterium necrophorum',
#   'susceptible_min_mm': None,
#   'resistant_max_mm': None,
#   'intermediate_min_mm': None,
#   'intermediate_max_mm': None},
#  ...]

# %%
extract_all_breakpoints()
# Out:
# Found 41 sheets. Processing...
# -> Skipping sheet (in blacklist): Content
# -> Skipping sheet (in blacklist): Changes
# -> Skipping sheet (in blacklist): Notes
# -> Skipping sheet (in blacklist): Guidance
# -> Skipping sheet (in blacklist): Dosages
# -> Skipping sheet (in blacklist): Technical uncertainty
# Processing data for: Enterobacterales
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Pseudomonas
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: S.maltophilia
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Acinetobacter
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Staphylococcus
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Enterococcus
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Streptococcus A,B,C,G
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: S.pneumoniae
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Viridans group streptococci
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: H.influenzae
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: M.catarrhalis
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: N.gonorrhoeae
#   -> Could not find 'Zone diameter breakpoints' header in N.gonorrhoeae. Skipping.
# Processing data for: N.meningitidis
#   -> Could not find 'Zone diameter breakpoints' header in N.meningitidis. Skipping.
# Processing data for: Anaerobic bacteria
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: H.pylori
#   -> Could not find 'Zone diameter breakpoints' header in H.pylori. Skipping.
# Processing data for: L.monocytogenes
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Pasteurella
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: C.jejuni_C.coli
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Corynebacterium
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: C.diphtheriae_C.ulcerans
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: A.sanguinicola_A.urinae
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: K.kingae
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Aeromonas
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: A.xylosoxidans
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Vibrio
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: Bacillus
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: B.anthracis
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: B.melitensis
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: B.pseudomallei
#   -> S/R breakpoint columns not found. Skipping.
# Processing data for: B.cepacia
#   -> Could not find 'Zone diameter breakpoints' header in B.cepacia. Skipping.
# -> Skipping sheet (in blacklist): L.pneumophila
# -> Skipping sheet (in blacklist): M.tuberculosis
# -> Skipping sheet (in blacklist): Topical agents
# -> Skipping sheet (in blacklist): PK PD breakpoints
# -> Skipping sheet (in blacklist): PK PD cutoffs
#
# --- Data Extraction Complete ---
# []
